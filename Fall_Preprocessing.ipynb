# %%
import pandas as pd
import seaborn as sb

# %%
ACC = pd.read_csv("ACC1.csv")
sb.lineplot(y = "x", x = 'time', data = ACC)
sb.lineplot(y = "y", x = 'time', data = ACC)
sb.lineplot(y = "z", x = 'time', data = ACC)
# Out:
# <AxesSubplot:xlabel='time', ylabel='x'>

# %%
GYR = pd.read_csv("GYR1.csv")
sb.lineplot(y = "x", x = 'time', data = GYR)
sb.lineplot(y = "y", x = 'time', data = GYR)
sb.lineplot(y = "z", x = 'time', data = GYR)
# Out:
# <AxesSubplot:xlabel='time', ylabel='x'>

# %%
ACC.iloc[-1:,3:4]
# Out:
#              time
# 67  1669833789890

# %%
GYR = GYR[GYR.time<1669833789890]

# %%
def fall_preprocess(ACC,GYR):
    ACC = ACC.rename(columns={"x":"accx","y":"accy","z":"accz"})
    GYR = GYR.rename(columns={"x":"gyrx","y":"gyry","z":"gyrz"})
    temptime = []
    for i in range(len(ACC)):
        temptime.append(int(ACC["time"][i]/100))
    ACC['UpdatedTime'] = temptime
    ACC = ACC.drop(columns=["time"])
    temptime = []
    for i in range(len(GYR)):
        temptime.append(int(GYR["time"][i]/100))
    GYR['UpdatedTime'] = temptime
    GYR = GYR.drop(columns=["time"])
    Maindf = pd.merge(ACC, GYR, on='UpdatedTime')
    for i in range(len(Maindf)-1):
        if(Maindf.UpdatedTime[i] == Maindf.UpdatedTime[i+1]):
            Maindf = Maindf.drop(labels=[i])
    Maindf.index = range(0,len(Maindf),1)
    return Maindf

# %%
df1 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC2.csv")
sb.lineplot(y = "x", x = 'time', data = ACC)
sb.lineplot(y = "y", x = 'time', data = ACC)
sb.lineplot(y = "z", x = 'time', data = ACC)
# Out:
# <AxesSubplot:xlabel='time', ylabel='x'>

# %%
GYR = pd.read_csv("GYR2.csv")
sb.lineplot(y = "x", x = 'time', data = GYR)
sb.lineplot(y = "y", x = 'time', data = GYR)
sb.lineplot(y = "z", x = 'time', data = GYR)
# Out:
# <AxesSubplot:xlabel='time', ylabel='x'>

# %%
ACC.iloc[-1:,3:4]
# Out:
#               time
# 246  1669833868265

# %%
GYR = GYR[GYR.time<1669833868265]

# %%
df2 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC3.csv")
sb.lineplot(y = "x", x = 'time', data = ACC)
sb.lineplot(y = "y", x = 'time', data = ACC)
sb.lineplot(y = "z", x = 'time', data = ACC)
# Out:
# <AxesSubplot:xlabel='time', ylabel='x'>

# %%
GYR = pd.read_csv("GYR3.csv")
sb.lineplot(y = "x", x = 'time', data = GYR)
sb.lineplot(y = "y", x = 'time', data = GYR)
sb.lineplot(y = "z", x = 'time', data = GYR)
# Out:
# <AxesSubplot:xlabel='time', ylabel='x'>

# %%
GYR.iloc[-1:,3:4]
# Out:
#               time
# 112  1669833937606

# %%
ACC = ACC[ACC.time<1669833937606]

# %%
df3 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC4.csv")
sb.lineplot(y = "x", x = 'time', data = ACC)
sb.lineplot(y = "y", x = 'time', data = ACC)
sb.lineplot(y = "z", x = 'time', data = ACC)
len(ACC)
# Out:
# 137

# %%
GYR = pd.read_csv("GYR4.csv")
sb.lineplot(y = "x", x = 'time', data = GYR)
sb.lineplot(y = "y", x = 'time', data = GYR)
sb.lineplot(y = "z", x = 'time', data = GYR)
# Out:
# <AxesSubplot:xlabel='time', ylabel='x'>

# %%
GYR.iloc[-1:,3:4]
# Out:
#              time
# 82  1669833995240

# %%
ACC = ACC[ACC.time<1669833995240]

# %%
df4 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC5.csv")
sb.lineplot(y = "x", x = 'time', data = ACC)
sb.lineplot(y = "y", x = 'time', data = ACC)
sb.lineplot(y = "z", x = 'time', data = ACC)
# Out:
# <AxesSubplot:xlabel='time', ylabel='x'>

# %%
GYR = pd.read_csv("GYR5.csv")
sb.lineplot(y = "x", x = 'time', data = GYR)
sb.lineplot(y = "y", x = 'time', data = GYR)
sb.lineplot(y = "z", x = 'time', data = GYR)
# Out:
# <AxesSubplot:xlabel='time', ylabel='x'>

# %%
GYR.iloc[-1:,3:4]
# Out:
#              time
# 93  1669834024648

# %%
ACC = ACC[ACC.time<1669834024648]

# %%
df5 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC6.csv")
GYR = pd.read_csv("GYR6.csv")
GYR.iloc[-1:,3:4]
# Out:
#              time
# 37  1669834192343

# %%
ACC = ACC[ACC.time<1669834192343]

# %%
df6 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC7.csv")
GYR = pd.read_csv("GYR7.csv")
GYR.iloc[-1:,3:4]
# Out:
#               time
# 108  1669834216205

# %%
ACC = ACC[ACC.time<1669834216205]

# %%
df7 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC8.csv")
GYR = pd.read_csv("GYR8.csv")
GYR.iloc[-1:,3:4]
# Out:
#              time
# 77  1669834240602

# %%
ACC = ACC[ACC.time<1669834240602]

# %%
df8 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC9.csv")
GYR = pd.read_csv("GYR9.csv")
GYR.iloc[-1:,3:4]
# Out:
#              time
# 76  1669834292209

# %%
ACC = ACC[ACC.time<1669834292209]

# %%
df9 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC7.csv")
GYR = pd.read_csv("GYR7.csv")
GYR.iloc[-1:,3:4]
# Out:
#               time
# 108  1669834216205

# %%
ACC = ACC[ACC.time<1669834216205]

# %%
df7 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC10.csv")
GYR = pd.read_csv("GYR10.csv")
GYR.iloc[-1:,3:4]
# Out:
#               time
# 105  1669834341324

# %%
ACC = ACC[ACC.time<1669834341324]

# %%
df10 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC11.csv")
GYR = pd.read_csv("GYR11.csv")
GYR.iloc[-1:,3:4]
# Out:
#              time
# 97  1669834372032

# %%
ACC = ACC[ACC.time<1669834372032]

# %%
df11 = fall_preprocess(ACC,GYR)

# %%
dffirstten = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])

# %%
dffirstten
# Out:
#         accx      accy      accz  UpdatedTime      gyrx      gyry      gyrz
# 0   0.035706 -0.491318 -0.929001  16698337865 -0.014996  0.110269  0.105325
# 1   0.023544 -0.467896 -0.879837  16698337866 -0.154709  0.159001  0.080853
# 2   0.040985 -0.461624 -0.865219  16698337867  0.079161 -0.008376  0.044593
# 3   0.039124 -0.432373 -0.935333  16698337868 -0.123960 -0.149399 -0.095729
# 4   0.019333 -0.429657 -0.853760  16698337869 -0.031151  0.139439  0.083289
# ..       ...       ...       ...          ...       ...       ...       ...
# 46  0.542130 -0.219223 -0.714401  16698343408  0.426533 -0.371337  0.201823
# 47  0.506409 -0.245789 -0.872650  16698343409  0.032203  0.014343 -0.029272
# 48  0.529556 -0.222183 -0.944382  16698343410  0.105903 -0.065695  0.028635
# 49  0.481415 -0.287674 -0.786758  16698343411  0.066875  0.011770 -0.073166
# 50  0.429474 -0.302231 -0.674438  16698343412 -0.110638 -0.212277  0.038429
#
# [438 rows x 7 columns]

# %%
ACC = pd.read_csv("ACC12.csv")
GYR = pd.read_csv("GYR12.csv")
GYR.iloc[-1:,3:4]
# Out:
#              time
# 79  1669834401668

# %%
ACC = ACC[ACC.time<1669834401668]

# %%
df12 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC13.csv")
GYR = pd.read_csv("GYR13.csv")
GYR.iloc[-1:,3:4]
# Out:
#              time
# 99  1669834434779

# %%
ACC = ACC[ACC.time<1669834434779]

# %%
df13 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC14.csv")
GYR = pd.read_csv("GYR14.csv")
GYR.iloc[-1:,3:4]
# Out:
#              time
# 86  1669834459529

# %%
ACC = ACC[ACC.time<1669834459529]

# %%
df14 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC15.csv")
GYR = pd.read_csv("GYR15.csv")
GYR.iloc[-1:,3:4]
# Out:
#              time
# 94  1669834515191

# %%
ACC = ACC[ACC.time<1669834515191]

# %%
df15 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC16.csv")
GYR = pd.read_csv("GYR16.csv")
GYR.iloc[-1:,3:4]
# Out:
#              time
# 96  1669834610654

# %%
ACC = ACC[ACC.time<1669834610654]

# %%
df16 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC17.csv")
GYR = pd.read_csv("GYR17.csv")
GYR.iloc[-1:,3:4]
# Out:
#               time
# 246  1669834651334

# %%
ACC = ACC[ACC.time<1669834651334]

# %%
df17 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC18.csv")
GYR = pd.read_csv("GYR18.csv")
GYR.iloc[-1:,3:4]
# Out:
#              time
# 46  1669834666323

# %%
ACC = ACC[ACC.time<1669834666323]

# %%
df18 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC19.csv")
GYR = pd.read_csv("GYR19.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 40  1669834699266

# %%
GYR = GYR[GYR.time<1669834699266]

# %%
df19 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC20.csv")
GYR = pd.read_csv("GYR20.csv")
ACC.iloc[-1:,3:4]
# Out:
#               time
# 100  1669834725598

# %%
GYR = GYR[GYR.time<1669834725598]

# %%
df20 = fall_preprocess(ACC,GYR)

# %%
dfsecondten = pd.concat([df11,df12,df13,df14,df15,df16,df17,df18,df19,df20])

# %%
ACC = pd.read_csv("ACC21.csv")
GYR = pd.read_csv("GYR21.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 75  1669834761606

# %%
GYR = GYR[GYR.time<1669834761606]

# %%
df21 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC22.csv")
GYR = pd.read_csv("GYR22.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 80  1669834784003

# %%
GYR = GYR[GYR.time<1669834784003]

# %%
df22 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC25.csv")
GYR = pd.read_csv("GYR25.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 46  1669834868153

# %%
GYR = GYR[GYR.time<1669834868153]

# %%
df25 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC23.csv")
GYR = pd.read_csv("GYR23.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 38  1669834810183

# %%
GYR = GYR[GYR.time<1669834810183]

# %%
df23 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC24.csv")
GYR = pd.read_csv("GYR24.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 50  1669834837341

# %%
GYR = GYR[GYR.time<1669834837341]

# %%
df24 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC26.csv")
GYR = pd.read_csv("GYR26.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 75  1669834889374

# %%
GYR = GYR[GYR.time<1669834889374]

# %%
df26 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC27.csv")
GYR = pd.read_csv("GYR27.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 37  1669834917530

# %%
GYR = GYR[GYR.time<1669834917530]

# %%
df27 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC28.csv")
GYR = pd.read_csv("GYR28.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 38  1669834938071

# %%
GYR = GYR[GYR.time<1669834938071]

# %%
df28 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC29.csv")
GYR = pd.read_csv("GYR29.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 30  1669834959192

# %%
GYR = GYR[GYR.time<1669834959192]

# %%
df29 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC30.csv")
GYR = pd.read_csv("GYR30.csv")
ACC.iloc[-1:,3:4]
# Out:
#               time
# 114  1669834983157

# %%
GYR = GYR[GYR.time<1669834983157]

# %%
df30 = fall_preprocess(ACC,GYR)

# %%
dfthirdten = pd.concat([df21,df22,df23,df24,df25,df26,df27,df28,df29,df30])

# %%
ACC = pd.read_csv("ACC31.csv")
GYR = pd.read_csv("GYR31.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 35  1669835015002

# %%
GYR = GYR[GYR.time<1669835015002]

# %%
df31 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC32.csv")
GYR = pd.read_csv("GYR32.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 36  1669835044877

# %%
GYR = GYR[GYR.time<1669835044877]

# %%
df32 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC33.csv")
GYR = pd.read_csv("GYR33.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 33  1669835068398

# %%
GYR = GYR[GYR.time<1669835068398]

# %%
df33 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC34.csv")
GYR = pd.read_csv("GYR34.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 36  1669835090947

# %%
GYR = GYR[GYR.time<1669835090947]

# %%
df34 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC35.csv")
GYR = pd.read_csv("GYR35.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 34  1669835115459

# %%
GYR = GYR[GYR.time<1669835115459]

# %%
df35 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC36.csv")
GYR = pd.read_csv("GYR36.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 36  1669835134922

# %%
GYR = GYR[GYR.time<1669835134922]

# %%
df35 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC36.csv")
GYR = pd.read_csv("GYR36.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 36  1669835134922

# %%
GYR = GYR[GYR.time<1669835134922]

# %%
df36 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC37.csv")
GYR = pd.read_csv("GYR37.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 32  1669835154781

# %%
GYR = GYR[GYR.time<1669835154781]

# %%
df37 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC38.csv")
GYR = pd.read_csv("GYR33.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 37  1669835186695

# %%
GYR = GYR[GYR.time<1669835186695]

# %%
df38 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC39.csv")
GYR = pd.read_csv("GYR39.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 35  1669835207196

# %%
GYR = GYR[GYR.time<1669835207196]

# %%
df39 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC40.csv")
GYR = pd.read_csv("GYR40.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 37  1669835227498

# %%
GYR = GYR[GYR.time<1669835227498]

# %%
df40 = fall_preprocess(ACC,GYR)

# %%
dfforthten = pd.concat([df31,df32,df33,df34,df35,df36,df37,df38,df39,df40])

# %%
ACC = pd.read_csv("ACC41.csv")
GYR = pd.read_csv("GYR41.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 37  1669835304808

# %%
GYR = GYR[GYR.time<1669835304808]

# %%
df41 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC42.csv")
GYR = pd.read_csv("GYR42.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 84  1669835328961

# %%
GYR = GYR[GYR.time<1669835328961]

# %%
df40 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC40.csv")
GYR = pd.read_csv("GYR40.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 37  1669835227498

# %%
GYR = GYR[GYR.time<1669835207196]

# %%
df42 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC43.csv")
GYR = pd.read_csv("GYR43.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 66  1669835421636

# %%
GYR = GYR[GYR.time<1669835421636]

# %%
df43 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC44.csv")
GYR = pd.read_csv("GYR44.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 38  1669835443275

# %%
GYR = GYR[GYR.time<1669835443275]

# %%
df44 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC45.csv")
GYR = pd.read_csv("GYR45.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 42  1669835468153

# %%
GYR = GYR[GYR.time<1669835468153]

# %%
df45 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC46.csv")
GYR = pd.read_csv("GYR46.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 50  1669835495445

# %%
GYR = GYR[GYR.time<1669835495445]

# %%
df46 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC47.csv")
GYR = pd.read_csv("GYR47.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 33  1669835531436

# %%
GYR = GYR[GYR.time<1669835531436]

# %%
df47 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC48.csv")
GYR = pd.read_csv("GYR48.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 34  1669835557199

# %%
GYR = GYR[GYR.time<1669835557199]

# %%
df48 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC49.csv")
GYR = pd.read_csv("GYR49.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 39  1669835579203

# %%
GYR = GYR[GYR.time<1669835207196]

# %%
df49 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC50.csv")
GYR = pd.read_csv("GYR50.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 40  1669835601783

# %%
GYR = GYR[GYR.time<1669835601783]

# %%
df50 = fall_preprocess(ACC,GYR)

# %%
dffifthten = pd.concat([df41,df42,df43,df44,df45,df46,df47,df48,df49,df50])

# %%
ACC = pd.read_csv("ACC51.csv")
GYR = pd.read_csv("GYR51.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 74  1669835622692

# %%
GYR = GYR[GYR.time<1669835622692]

# %%
df51 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC52.csv")
GYR = pd.read_csv("GYR52.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 30  1669835644780

# %%
GYR = GYR[GYR.time<1669835644780]

# %%
df52 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC53.csv")
GYR = pd.read_csv("GYR53.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 32  1669835668305

# %%
GYR = GYR[GYR.time<1669835668305]

# %%
df53 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC54.csv")
GYR = pd.read_csv("GYR54.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 48  1669835693160

# %%
GYR = GYR[GYR.time<1669835693160]

# %%
df54 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC55.csv")
GYR = pd.read_csv("GYR55.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 35  1669835716811

# %%
GYR = GYR[GYR.time<1669835716811]

# %%
df55 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC50.csv")
GYR = pd.read_csv("GYR50.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 40  1669835601783

# %%
GYR = GYR[GYR.time<1669835207196]

# %%
df44 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC56.csv")
GYR = pd.read_csv("GYR56.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 32  1669835735322

# %%
GYR = GYR[GYR.time<1669835735322]

# %%
df56 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC58.csv")
GYR = pd.read_csv("GYR58.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 30  1669836016343

# %%
GYR = GYR[GYR.time<1669836016343]

# %%
df58 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC57.csv")
GYR = pd.read_csv("GYR57.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 36  1669835950742

# %%
GYR = GYR[GYR.time<1669835207196]

# %%
df57 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC59.csv")
GYR = pd.read_csv("GYR59.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 33  1669836067148

# %%
GYR = GYR[GYR.time<1669836067148]

# %%
df59 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC60.csv")
GYR = pd.read_csv("GYR60.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 38  1669836088745

# %%
GYR = GYR[GYR.time<1669836088745]

# %%
df60 = fall_preprocess(ACC,GYR)

# %%
dfsixthten = pd.concat([df51,df52,df53,df54,df55,df56,df57,df58,df59,df60])

# %%
ACC = pd.read_csv("ACC61.csv")
GYR = pd.read_csv("GYR61.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 32  1669836109265

# %%
GYR = GYR[GYR.time<1669836109265]

# %%
df61 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC62.csv")
GYR = pd.read_csv("GYR62.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 33  1669836132366

# %%
GYR = GYR[GYR.time<1669836132366]

# %%
df62 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC63.csv")
GYR = pd.read_csv("GYR63.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 44  1669836157628

# %%
GYR = GYR[GYR.time<1669836157628]

# %%
df63 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC64.csv")
GYR = pd.read_csv("GYR64.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 32  1669836177442

# %%
GYR = GYR[GYR.time<1669836177442]

# %%
df64 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC65.csv")
GYR = pd.read_csv("GYR65.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 31  1669836197177

# %%
GYR = GYR[GYR.time<1669836197177]

# %%
df65 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC66.csv")
GYR = pd.read_csv("GYR66.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 31  1669836219266

# %%
GYR = GYR[GYR.time<1669836219266]

# %%
df66 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC67.csv")
GYR = pd.read_csv("GYR67.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 47  1669836242780

# %%
GYR = GYR[GYR.time<1669836242780]

# %%
df67 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC68.csv")
GYR = pd.read_csv("GYR68.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 31  1669836267296

# %%
GYR = GYR[GYR.time<1669836267296]

# %%
df68 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC69.csv")
GYR = pd.read_csv("GYR69.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 31  1669836306489

# %%
GYR = GYR[GYR.time<1669836306489]

# %%
df69 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC70.csv")
GYR = pd.read_csv("GYR70.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 28  1669836325325

# %%
GYR = GYR[GYR.time<1669836325325]

# %%
df70 = fall_preprocess(ACC,GYR)

# %%
dfseventhten = pd.concat([df61,df62,df63,df64,df65,df66,df67,df68,df69,df70])

# %%
ACC = pd.read_csv("ACC71.csv")
GYR = pd.read_csv("GYR71.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 43  1669836347867

# %%
GYR = GYR[GYR.time<1669836347867]

# %%
df71 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC72.csv")
GYR = pd.read_csv("GYR72.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 47  1669836377653

# %%
GYR = GYR[GYR.time<1669836377653]

# %%
df72 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC73.csv")
GYR = pd.read_csv("GYR73.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 49  1669836404896

# %%
GYR = GYR[GYR.time<1669836404896]

# %%
df73 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC74.csv")
GYR = pd.read_csv("GYR74.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 39  1669836424795

# %%
GYR = GYR[GYR.time<1669836424795]

# %%
df74 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC75.csv")
GYR = pd.read_csv("GYR75.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 30  1669836450977

# %%
GYR = GYR[GYR.time<1669836450977]

# %%
df75 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC76.csv")
GYR = pd.read_csv("GYR76.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 30  1669836470547

# %%
GYR = GYR[GYR.time<1669836470547]

# %%
df76 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC77.csv")
GYR = pd.read_csv("GYR77.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 67  1669836490347

# %%
GYR = GYR[GYR.time<1669836490347]

# %%
df77 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC78.csv")
GYR = pd.read_csv("GYR78.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 30  1669836509624

# %%
GYR = GYR[GYR.time<1669836509624]

# %%
df78 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC79.csv")
GYR = pd.read_csv("GYR79.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 33  1669836529610

# %%
GYR = GYR[GYR.time<1669836529610]

# %%
df79 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC80.csv")
GYR = pd.read_csv("GYR80.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 29  1669836548472

# %%
GYR = GYR[GYR.time<1669836548472]

# %%
df80 = fall_preprocess(ACC,GYR)

# %%
dfeigthten = pd.concat([df71,df72,df73,df74,df75,df76,df77,df78,df79,df80])

# %%
ACC = pd.read_csv("ACC81.csv")
GYR = pd.read_csv("GYR81.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 88  1669836570020

# %%
GYR = GYR[GYR.time<1669836570020]

# %%
df81 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC82.csv")
GYR = pd.read_csv("GYR82.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 38  1669836589895

# %%
GYR = GYR[GYR.time<1669836548472]

# %%
df82 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC83.csv")
GYR = pd.read_csv("GYR83.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 33  1669836609363

# %%
GYR = GYR[GYR.time<1669836609363]

# %%
df83 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC84.csv")
GYR = pd.read_csv("GYR84.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 31  1669836648531

# %%
GYR = GYR[GYR.time<1669836648531]

# %%
df84 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC85.csv")
GYR = pd.read_csv("GYR85.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 30  1669836669632

# %%
GYR = GYR[GYR.time<1669836669632]

# %%
df85 = fall_preprocess(ACC,GYR)

# %%
ACC = pd.read_csv("ACC86.csv")
GYR = pd.read_csv("GYR86.csv")
ACC.iloc[-1:,3:4]
# Out:
#              time
# 35  1669836690524

# %%
GYR = GYR[GYR.time<1669836690524]

# %%
df86 = fall_preprocess(ACC,GYR)

# %%
dfninthten = pd.concat([df81,df82,df83,df84,df85,df86])

# %%
FALL = pd.concat([dffirstten,dfsecondten,dfthirdten,dfforthten,dffifthten,dfsixthten,dfseventhten,dfeigthten,dfninthten])

# %%
FALL
# Out:
#         accx      accy      accz  UpdatedTime      gyrx      gyry      gyrz
# 0   0.035706 -0.491318 -0.929001  16698337865 -0.014996  0.110269  0.105325
# 1   0.023544 -0.467896 -0.879837  16698337866 -0.154709  0.159001  0.080853
# 2   0.040985 -0.461624 -0.865219  16698337867  0.079161 -0.008376  0.044593
# 3   0.039124 -0.432373 -0.935333  16698337868 -0.123960 -0.149399 -0.095729
# 4   0.019333 -0.429657 -0.853760  16698337869 -0.031151  0.139439  0.083289
# ..       ...       ...       ...          ...       ...       ...       ...
# 31 -0.048462 -0.566284 -0.759766  16698366901 -0.149567  0.084094 -0.098193
# 32 -0.030380 -0.545227 -0.808517  16698366902  0.247947 -0.262248  0.098506
# 33 -0.066254 -0.578171 -0.762177  16698366903  0.017768 -0.291209  0.150634
# 34 -0.166382 -0.711716 -0.798477  16698366904 -0.145169 -0.238178  0.044167
# 35 -0.154388 -0.610977 -0.623581  16698366905 -0.391156  0.087943  0.053336
#
# [3132 rows x 7 columns]

# %%
FALL.index = range(0,len(FALL),1)

# %%
FALL
# Out:
#           accx      accy      accz  UpdatedTime      gyrx      gyry      gyrz
# 0     0.035706 -0.491318 -0.929001  16698337865 -0.014996  0.110269  0.105325
# 1     0.023544 -0.467896 -0.879837  16698337866 -0.154709  0.159001  0.080853
# 2     0.040985 -0.461624 -0.865219  16698337867  0.079161 -0.008376  0.044593
# 3     0.039124 -0.432373 -0.935333  16698337868 -0.123960 -0.149399 -0.095729
# 4     0.019333 -0.429657 -0.853760  16698337869 -0.031151  0.139439  0.083289
# ...        ...       ...       ...          ...       ...       ...       ...
# 3127 -0.048462 -0.566284 -0.759766  16698366901 -0.149567  0.084094 -0.098193
# 3128 -0.030380 -0.545227 -0.808517  16698366902  0.247947 -0.262248  0.098506
# 3129 -0.066254 -0.578171 -0.762177  16698366903  0.017768 -0.291209  0.150634
# 3130 -0.166382 -0.711716 -0.798477  16698366904 -0.145169 -0.238178  0.044167
# 3131 -0.154388 -0.610977 -0.623581  16698366905 -0.391156  0.087943  0.053336
#
# [3132 rows x 7 columns]

# %%
plotfallsdf =  FALL.iloc[0:500,:]

# %%
sb.lineplot(y = 'accx', x = 'UpdatedTime', data = plotfallsdf)
sb.lineplot(y = 'accy', x = 'UpdatedTime', data = plotfallsdf)
sb.lineplot(y = 'accz', x = 'UpdatedTime', data = plotfallsdf)
# Out:
# <AxesSubplot:xlabel='UpdatedTime', ylabel='accx'>

# %%
sb.lineplot(y = 'gyrx', x = 'UpdatedTime', data = plotfallsdf)
sb.lineplot(y = 'gyry', x = 'UpdatedTime', data = plotfallsdf)
sb.lineplot(y = 'gyrz', x = 'UpdatedTime', data = plotfallsdf)
# Out:
# <AxesSubplot:xlabel='UpdatedTime', ylabel='gyrx'>

# %%
Label = []
for i in range(len(FALL)):
    Label.append("fall")

# %%
FALL["Label"] = Label

# %%
FALL.to_csv("FALL.csv",index=False)
