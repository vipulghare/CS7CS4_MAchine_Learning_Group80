# %%
import pandas as pd
import seaborn as sb

# %%
def upstairs_data_odd(acc,gyr):
    ACC = pd.read_csv(acc)
    GYR = pd.read_csv(gyr)
    ACC = ACC.rename(columns={"x":"accx","y":"accy","z":"accz"})
    GYR = GYR.rename(columns={"x":"gyrx","y":"gyry","z":"gyrz"})
    temptime = []
    for i in range(len(ACC)):
        temptime.append(int(ACC["time"][i]/100))
    ACC['UpdatedTime'] = temptime
    ACC = ACC.drop(columns=["time"])
    temptime = []
    for i in range(len(GYR)):
        temptime.append(int(GYR["time"][i]/100))
    GYR['UpdatedTime'] = temptime
    GYR = GYR.drop(columns=["time"])
    Maindf1 = pd.merge(ACC, GYR, on='UpdatedTime')
    for i in range(len(Maindf1)-1):
        if((Maindf1.accx[i] == Maindf1.accx[i+1]) or (Maindf1.gyrx[i] == Maindf1.gyrx[i+1])):
            Maindf1 = Maindf1.drop(labels=[i])
    Maindf1.index = range(0,len(Maindf1),1)
    return Maindf1

# %%
df1 = upstairs_data_odd("ACC1.csv","GYR1.csv")

# %%
df1
# Out:
#          accx      accy      accz  UpdatedTime      gyrx      gyry      gyrz
# 0    0.048035 -0.316528 -0.903107  16698160916 -0.185081 -0.116196  0.110085
# 1   -0.053101 -0.262848 -1.031204  16698160917  0.045830 -0.546108  0.189391
# 2   -0.067001 -0.272980 -0.904190  16698160918 -0.123644 -0.234115 -0.048207
# 3   -0.110901 -0.255554 -0.925537  16698160919 -0.253013 -0.437749 -0.468041
# 4   -0.172440 -0.228378 -0.970474  16698160920 -0.458798 -0.522205 -0.569147
# ..        ...       ...       ...          ...       ...       ...       ...
# 607 -0.039047 -0.232529 -1.011398  16698161526 -0.908078  0.991196  1.049763
# 608 -0.079453 -0.341629 -0.953690  16698161527  2.045582  0.735334  0.372394
# 609 -0.046402 -0.416489 -0.836533  16698161528  0.280687  0.628928  0.421056
# 610 -0.015640 -0.472610 -0.888702  16698161529  0.003190  0.670829  0.723692
# 611  0.105423 -0.473114 -0.820145  16698161530 -1.384296  2.000429  1.133656
#
# [612 rows x 7 columns]

# %%
df5 = upstairs_data_odd("ACC5.csv","GYR5.csv")

# %%
df5
# Out:
#          accx      accy      accz  UpdatedTime      gyrx      gyry      gyrz
# 0    0.135635 -0.225388 -0.954880  16698167007 -0.438896  0.181134  0.245309
# 1    0.153000 -0.149826 -0.994110  16698167008 -0.123864  0.182173  0.437301
# 2    0.111603 -0.153473 -0.926514  16698167010  0.192527 -0.379115 -0.367320
# 3   -0.023361 -0.164322 -0.945450  16698167011  0.111277  0.250141  0.187422
# 4    0.037338 -0.260132 -0.977158  16698167012  0.144204 -0.438305 -0.033662
# ..        ...       ...       ...          ...       ...       ...       ...
# 725  0.539658 -0.705170 -0.991470  16698167736  0.660973  0.442228 -0.336137
# 726  0.309296 -0.471680 -0.812469  16698167737 -0.421666 -1.334782 -0.153064
# 727  0.303436 -0.529129 -0.816986  16698167738  0.116046 -0.383850 -0.039955
# 728  0.241928 -0.479507 -0.776459  16698167739  0.156993 -0.457265  0.159954
# 729  0.491959 -0.668808 -0.722916  16698167740  0.855277  1.358065  0.118949
#
# [730 rows x 7 columns]

# %%
df7 = upstairs_data_odd("ACC7.csv","GYR7.csv")

# %%
df7
# Out:
#          accx      accy      accz  UpdatedTime      gyrx      gyry      gyrz
# 
# Out:
#          accx      accy      accz  UpdatedTime      gyrx      gyry      gyrz
# 0   -0.072968 -0.503922 -1.149826  16698182345 -1.056817  0.266247  0.879601
# 1   -0.043839 -0.660355 -1.508530  16698182346 -0.346755 -0.797645 -0.697281
# 2   -0.074722 -0.483826 -0.985886  16698182347  0.464875  0.105559 -0.376948
# 3    0.011887 -0.334702 -0.570129  16698182348  0.525986 -0.493076 -0.437984
# 4    0.001205 -0.352615 -0.779343  16698182349 -0.383777 -0.257915 -0.283538
# ..        ...       ...       ...          ...       ...       ...       ...
# 710  0.401459 -0.339615 -0.789658  16698183055  0.559152  0.237197  0.115787
# 711  0.269211 -0.527695 -0.861496  16698183056  1.837033  1.357393 -0.463852
# 712  0.355972 -0.685181 -0.731735  16698183057  0.457037  0.326604 -0.141410
# 713  0.446320 -0.559448 -0.737442  16698183058  0.029932  0.300458 -0.035468
# 714  0.486389 -0.622116 -0.596924  16698183059  0.073931 -0.132593  0.297955
#
# [715 rows x 7 columns]

# %% [markdown]
# # notX--> 3,13,17

# %%
def upstairs_data_even(acc,gyr):
    ACC = pd.read_csv(acc)
    ACC = ACC.rename(columns={"x":"accx","y":"accy","z":"accz"})
    GYR = pd.read_csv(gyr)
    GYR = GYR.rename(columns={"x":"gyrx","y":"gyry","z":"gyrz"})
    temptime = []
    for i in range(len(ACC)):
        temptime.append(int(ACC["time"][i]/100))
    ACC['UpdatedTime'] = temptime
    ACC = ACC.drop(columns=["time"])
    temptime = []
    for i in range(len(GYR)):
        temptime.append(int(GYR["time"][i]/100))
    GYR['UpdatedTime'] = temptime
    GYR = GYR.drop(columns=["time"])
    Maindf = pd.merge(ACC, GYR, on='UpdatedTime')
    for i in range(len(Maindf)-1):
        if(Maindf.UpdatedTime[i] == Maindf.UpdatedTime[i+1]):
            if((Maindf.accx[i] == Maindf.accx[i+1]) or (Maindf.gyrx[i] == Maindf.gyrx[i+1])):
                Maindf = Maindf.drop(labels=[i])
    Maindf.index = range(0,len(Maindf),1)
    for i in range(len(Maindf)-1):
        if(Maindf.UpdatedTime[i] == Maindf.UpdatedTime[i+1]):
            if((Maindf.accx[i] == Maindf.accx[i+1]) or (Maindf.gyrx[i] == Maindf.gyrx[i+1])):
                Maindf = Maindf.drop(labels=[i])
    Maindf.index = range(0,len(Maindf),1)
    return Maindf

# %%
df2 = upstairs_data_even("ACC2.csv","GYR2.csv")

# %%
df2
# Out:
#          accz      accy      accx  UpdatedTime      gyrz      gyry      gyrx
# 0    0.893378  0.111965 -0.285923  16698160929  0.085525  1.495312  0.905850
# 1    0.894908  0.058430 -0.002753  16698160930  0.765188  0.731500 -0.108213
# 2    0.971784  0.071385  0.197820  16698160931 -0.395862  0.468462  0.330687
# 3    1.591874 -0.034981 -0.277572  16698160932 -0.164725  0.323537 -0.982850
# 4    0.767648  0.172230 -0.190172  16698160933 -0.034787 -1.575750 -0.130625
# ..        ...       ...       ...          ...       ...       ...       ...
# 595  1.001061  0.258911 -0.121142  16698161529  0.635250  0.241588  0.154825
# 596  0.926815  0.315811 -0.151122  16698161530  0.506413  0.434363  0.256025
# 597  0.865326  0.311421 -0.236059  16698161531  0.301812  0.312950  0.418000
# 598  0.811592  0.347320 -0.247072  16698161532  0.145200 -0.031212  0.475475
# 599  0.941300  0.343129 -0.236365  16698161533  0.068475 -0.242137 -0.119900
#
# [600 rows x 7 columns]

# %%
df4 = upstairs_data_even("ACC4.csv","GYR4.csv")

# %%
df6 = upstairs_data_even("ACC6.csv","GYR6.csv")

# %%
df8 = upstairs_data_even("ACC8.csv","GYR8.csv")

# %%
df10 = upstairs_data_even("ACC10.csv","GYR10.csv")

# %%
df12 = upstairs_data_even("ACC12.csv","GYR12.csv")

# %%
df14 = upstairs_data_even("ACC14.csv","GYR14.csv")

# %%
df16 = upstairs_data_even("ACC16.csv","GYR16.csv")

# %%
DOWNSTAIRS = pd.concat([df1,df2,df4,df5,df6,df7,df8,df9,df10,df11,df12,df14,df15,df16])

# %%
DOWNSTAIRS
# Out:
#          accx      accy      accz  UpdatedTime      gyrx      gyry      gyrz
# 0    0.048035 -0.316528 -0.903107  16698160916 -0.185081 -0.116196  0.110085
# 1   -0.053101 -0.262848 -1.031204  16698160917  0.045830 -0.546108  0.189391
# 2   -0.067001 -0.272980 -0.904190  16698160918 -0.123644 -0.234115 -0.048207
# 3   -0.110901 -0.255554 -0.925537  16698160919 -0.253013 -0.437749 -0.468041
# 4   -0.172440 -0.228378 -0.970474  16698160920 -0.458798 -0.522205 -0.569147
# ..        ...       ...       ...          ...       ...       ...       ...
# 651 -0.218010  0.382195  0.889708  16698183099 -0.324500  0.830638  0.743875
# 652 -0.231991  0.380971  0.749078  16698183100 -0.262762  0.820050  1.109350
# 653 -0.304997  0.362708  0.918356  16698183101 -0.525800  0.869000  1.200925
# 654 -0.499253  0.405643  0.954959  16698183102 -0.677050  0.653812  1.474687
# 655 -0.398500  0.372910  0.873387  16698183103 -0.747450  0.681450  1.594038
#
# [9753 rows x 7 columns]

# %%
DOWNSTAIRS.index = range(0,len(UPSTAIRS),1)

# %%
plotdownstairsdf =  DOWNSTAIRS.iloc[0:500,:]

# %%
sb.lineplot(y = 'accx', x = 'UpdatedTime', data = plotdownstairsdf)
sb.lineplot(y = 'accy', x = 'UpdatedTime', data = plotdownstairsdf)
sb.lineplot(y = 'accz', x = 'UpdatedTime', data = plotdownstairsdf)
# Out:
# <AxesSubplot:xlabel='UpdatedTime', ylabel='accx'>

# %%
sb.lineplot(y = 'gyrx', x = 'UpdatedTime', data = plotdownstairsdf)
sb.lineplot(y = 'gyry', x = 'UpdatedTime', data = plotdownstairsdf)
sb.lineplot(y = 'gyrz', x = 'UpdatedTime', data = plotdownstairsdf)
# Out:
# <AxesSubplot:xlabel='UpdatedTime', ylabel='gyrx'>

# %%
Label = []
for i in range(len(DOWNSTAIRS)):
    Label.append("downstairs")

# %%
DOWNSTAIRS["Label"] = Label

# %%
DOWNSTAIRS.to_csv("DOWNSTAIRS.csv",index=False)
